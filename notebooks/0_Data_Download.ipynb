# %% [markdown]
# # 0. Data Download
#
# > **Purpose:**
# > This notebook provides instructions for obtaining the raw data required to reproduce the experiments.
# > The actual web-scraping code is **not included** to respect the manufacturers’ terms of service and to ensure ethical data usage.
#
# ---
#
# ### 📦 Step 1 — Download Product Data
#
# Please download the selected **product datasheets** and corresponding **AASX files** directly from the respective manufacturers’ websites.
# A list of official URLs is provided in the file:
#
#
# `notebooks/urls.txt`
#
#
# Before downloading or automating any retrieval process, make sure to:
#
# - **Comply with each manufacturer’s Terms of Service.**
#   When in doubt, contact the manufacturer directly for clarification or permission.
# - **Check the site’s `robots.txt`** file to confirm that automated access is allowed and to avoid excessive requests that might be interpreted as a cyberattack.
#
# ---
#
# ### 📁 Step 2 — Folder Structure and Naming Convention
#
# All downloaded files should be saved in:
#
# `/app/data/raw/sample/`
#
#
# Each product must be stored in a **separate subfolder** following this naming scheme:
#
# `<Company>_<product_id>/`
#
# Example:
#
# `/app/data/raw/sample/Siemens_6ES71314BF000AA0/`
#
#
# This structure ensures that each product can be uniquely identified across manufacturers, avoiding potential ID collisions.
#
# ---
#
# ### 📄 Step 3 — File Contents per Product Folder
#
# Each product folder should contain:
#
# - One `*.aasx` file
# - One `*.pdf` product datasheet
#   (unless the datasheet is already embedded within the `.aasx` file)
#
# ---
#
# > ⚠️ **Important Notice**
# > Redistribution of manufacturer data is **not permitted** unless explicitly authorized.
# > All users must obtain their own copies directly from the original sources.
